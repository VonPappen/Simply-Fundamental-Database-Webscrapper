# %%
import sys, os

sys.path.append(
    os.path.dirname(
        os.path.abspath(
            ""
        )
    )
)

from scrapping_sources.Macrotrend import Macrotrend
df = Macrotrend().arrange_data('AAPL', 'balance-sheet', 'annual')
# Out:
# AAPL <Response [200]>
#            date statement ticker security_id  \
# 0    2020-09-30      BS-A   AAPL        None
# 1    2020-09-30      BS-A   AAPL        None
# 2    2020-09-30      BS-A   AAPL        None
# 3    2020-09-30      BS-A   AAPL        None
# 4    2020-09-30      BS-A   AAPL        None
# ..          ...       ...    ...         ...
# 347  2005-09-30      BS-A   AAPL        None
# 348  2005-09-30      BS-A   AAPL        None
# 349  2005-09-30      BS-A   AAPL        None
# 350  2005-09-30      BS-A   AAPL        None
# 351  2005-09-30      BS-A   AAPL        None
#
#                                       line_item        amount  \
# 0                                   Receivables   37445.00000
# 1                                     Inventory    4061.00000
# 2                             Pre-Paid Expenses
# 3                          Other Current Assets   11264.00000
# 4                          Total Current Assets  143713.00000
# ...

# %%
# Out:
#            date statement ticker security_id        statement_id
# 0    2020-09-30      BS-A   AAPL        None  BS-A_20200930_AAPL
# 22   2019-09-30      BS-A   AAPL        None  BS-A_20190930_AAPL
# 44   2018-09-30      BS-A   AAPL        None  BS-A_20180930_AAPL
# 66   2017-09-30      BS-A   AAPL        None  BS-A_20170930_AAPL
# 88   2016-09-30      BS-A   AAPL        None  BS-A_20160930_AAPL
# 110  2015-09-30      BS-A   AAPL        None  BS-A_20150930_AAPL
# 132  2014-09-30      BS-A   AAPL        None  BS-A_20140930_AAPL
# 154  2013-09-30      BS-A   AAPL        None  BS-A_20130930_AAPL
# 176  2012-09-30      BS-A   AAPL        None  BS-A_20120930_AAPL
# 198  2011-09-30      BS-A   AAPL        None  BS-A_20110930_AAPL
# 220  2010-09-30      BS-A   AAPL        None  BS-A_20100930_AAPL
# 242  2009-09-30      BS-A   AAPL        None  BS-A_20090930_AAPL
# 264  2008-09-30      BS-A   AAPL        None  BS-A_20080930_AAPL
# ...
